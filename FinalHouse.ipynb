# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1.	Загрузить train.csv, вывести 10 строк.
data = pd.read_csv('house.csv')
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
#2.	Посмотреть .info() и .shape.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
#3.	Вывести список колонок и их типы.
data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#4.	Удалить все неиспользуемые признаки (оставить только нужные 7 + SalePrice).
data = data[['GrLivArea', 'YearBuilt', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'OverallQual',
            'Neighborhood', 'SalePrice']]

# %%
data
# Out:
#       GrLivArea  YearBuilt  GarageCars  TotalBsmtSF  FullBath  OverallQual  \
# 0          1710       2003           2          856         2            7
# 1          1262       1976           2         1262         2            6
# 2          1786       2001           2          920         2            7
# 3          1717       1915           3          756         1            7
# 4          2198       2000           3         1145         2            8
# ...         ...        ...         ...          ...       ...          ...
# 1455       1647       1999           2          953         2            6
# 1456       2073       1978           2         1542         2            6
# 1457       2340       1941           1         1152         2            7
# 1458       1078       1950           1         1078         1            5
# 1459       1256       1965           1         1256         1            5
#
#      Neighborhood  SalePrice
# 0         CollgCr     208500
# ...

# %%
#5.	Сохранить облегчённый датасет в отдельный CSV (data_clean.csv).
data.to_csv('data_clean.csv', index=False)

# %%
#6.	Сколько уникальных районов (Neighborhood)?
data['Neighborhood'].nunique()
# Out:
# 25

# %%
#7.	Средняя цена по району — топ 5 дорогих районов.
data.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=False).head(5).round()
# Out:
# Neighborhood
# NoRidge    335295.0
# NridgHt    316271.0
# StoneBr    310499.0
# Timber     242247.0
# Veenker    238773.0
# Name: SalePrice, dtype: float64

# %%
#8.	Сколько домов было построено после 2000 года?
count_houses = (data['YearBuilt'] > 2000).sum()
print(f'Количества домов было построено: {count_houses}')
# Out:
# Количества домов было построено: 364

# %%
#9.	Средняя жилая площадь (GrLivArea) по уровню качества (OverallQual).
avg_area = (data.groupby('OverallQual')['GrLivArea'].mean().round())
print(f'Средняя жилая площадь: {avg_area}')
# Out:
# Средняя жилая площадь: OverallQual
# 1      619.0
# 2      573.0
# 3     1119.0
# 4     1107.0
# 5     1251.0
# 6     1466.0
# 7     1704.0
# 8     1948.0
# 9     2078.0
# 10    3001.0
# Name: GrLivArea, dtype: float64

# %%
#10.	Есть ли дома с нулевым подвалом? Посчитать долю таких домов.
count_zero = (data['TotalBsmtSF'] == 0).sum()
count_zero
# Out:
# np.int64(37)

# %%
total_house = data['TotalBsmtSF'].shape[0]

# %%
print(f'{round((count_zero * 100) / total_house)} %')
# Out:
# 3 %

# %%
#11.	Группировка по GarageCars и средняя цена.
price = (data.groupby('GarageCars')['SalePrice'].mean().round(0))
print(f'средняя цена: {price}')
# Out:
# средняя цена: GarageCars
# 0    103317.0
# 1    128117.0
# 2    183852.0
# 3    309636.0
# 4    192656.0
# Name: SalePrice, dtype: float64

# %%
#12.	Сколько домов имеют 2+ ванных комнаты (FullBath)?
count = (data['FullBath'] >= 2).sum()
print(f'Количества домов имеет 2+ ванных: {count}')
# Out:
# Количества домов имеет 2+ ванных: 801

# %%
#13.	Район с наибольшим количеством домов.
data['Neighborhood'].value_counts().head(1)
# Out:
# Neighborhood
# NAmes    225
# Name: count, dtype: int64

# %%
#14.	Корреляция GrLivArea, TotalBsmtSF, OverallQual, GarageCars с SalePrice.
new_data = data[['GrLivArea', 'TotalBsmtSF', 'OverallQual', 'GarageCars', 'SalePrice']]
new_data.corr()
# Out:
#              GrLivArea  TotalBsmtSF  OverallQual  GarageCars  SalePrice
# GrLivArea     1.000000     0.454868     0.593007    0.467247   0.708624
# TotalBsmtSF   0.454868     1.000000     0.537808    0.434585   0.613581
# OverallQual   0.593007     0.537808     1.000000    0.600671   0.790982
# GarageCars    0.467247     0.434585     0.600671    1.000000   0.640409
# SalePrice     0.708624     0.613581     0.790982    0.640409   1.000000

# %%
sns.heatmap(new_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#15.	Построить рейтинг районов по средней цене и сохранить в CSV.
rat_data = data.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=False).round()
rat_data.to_csv('rating_cvs', index=False)

# %% [markdown]
# Визуализация (Matplotlib & Seaborn)

# %%
#20.	Построить гистограмму SalePrice + распределение (Seaborn distplot).
sns.histplot(data=data, x='SalePrice', kde=True)
plt.show()

# %%
#21.	Построить boxplot: OverallQual vs SalePrice.
sns.boxplot(data=data, x='OverallQual', y='SalePrice')
plt.show()

# %%
#22.	Построить violinplot: Neighborhood vs SalePrice.
plt.figure(figsize=[6, 6])
sns.violinplot(data=data, y='Neighborhood', x='SalePrice')
plt.show()

# %%
#23.	Построить heatmap корреляции между 6 числовыми признаками.
corr_df6 = data[['GrLivArea', 'TotalBsmtSF', 'OverallQual', 'GarageCars', 'YearBuilt', 'SalePrice']]

# %%
sns.heatmap(corr_df6.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#24.	Построить scatterplot:
#•	GrLivArea vs SalePrice
#•	TotalBsmtSF vs SalePrice
#•	YearBuilt vs SalePrice
sns.scatterplot(data=data, x='GrLivArea', y='SalePrice')
plt.show()

# %%
sns.scatterplot(data=data, x='TotalBsmtSF', y='SalePrice')
plt.show()

# %%
sns.scatterplot(data=data, x='YearBuilt', y='SalePrice')
plt.show()

# %%
#25.	Построить barplot: средняя цена по GarageCars.
avg_price = data.groupby('GarageCars')['SalePrice'].mean().round()
print(avg_price)
# Out:
# GarageCars
# 0    103317.0
# 1    128117.0
# 2    183852.0
# 3    309636.0
# 4    192656.0
# Name: SalePrice, dtype: float64

# %%
sns.barplot(data=avg_price)
plt.show()

# %%
#26.	Построить линейную регрессию regplot для GrLivArea vs SalePrice.
sns.regplot(data=data, x='GrLivArea', y='SalePrice')
plt.show()

# %%
#27.	Построить pairplot по всем числовым признакам.
sns.pairplot(data[['SalePrice', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'YearBuilt', 'OverallQual', 'FullBath']])
plt.show()

# %%
#28.	Обработать пропущенные значения (если есть).
data.isnull().sum()
# Out:
# GrLivArea               0
# YearBuilt               0
# GarageCars              0
# TotalBsmtSF             0
# FullBath                0
# OverallQual             0
# SalePrice               0
# Neighborhood_Blueste    0
# Neighborhood_BrDale     0
# Neighborhood_BrkSide    0
# Neighborhood_ClearCr    0
# Neighborhood_CollgCr    0
# Neighborhood_Crawfor    0
# Neighborhood_Edwards    0
# Neighborhood_Gilbert    0
# Neighborhood_IDOTRR     0
# Neighborhood_MeadowV    0
# Neighborhood_Mitchel    0
# Neighborhood_NAmes      0
# Neighborhood_NPkVill    0
# Neighborhood_NWAmes     0
# Neighborhood_NoRidge    0
# Neighborhood_NridgHt    0
# Neighborhood_OldTown    0
# Neighborhood_SWISU      0
# Neighborhood_Sawyer     0
# Neighborhood_SawyerW    0
# Neighborhood_Somerst    0
# Neighborhood_StoneBr    0
# Neighborhood_Timber     0
# Neighborhood_Veenker    0
# dtype: int64

# %%
#29.	Преобразовать Neighborhood в числовой (one-hot или LabelEncoder).
data = pd.get_dummies(data, columns=['Neighborhood'], drop_first=True).astype(int)

# %%
data
# Out:
#       GrLivArea  YearBuilt  GarageCars  TotalBsmtSF  FullBath  OverallQual  \
# 0          1710       2003           2          856         2            7
# 1          1262       1976           2         1262         2            6
# 2          1786       2001           2          920         2            7
# 3          1717       1915           3          756         1            7
# 4          2198       2000           3         1145         2            8
# ...         ...        ...         ...          ...       ...          ...
# 1455       1647       1999           2          953         2            6
# 1456       2073       1978           2         1542         2            6
# 1457       2340       1941           1         1152         2            7
# 1458       1078       1950           1         1078         1            5
# 1459       1256       1965           1         1256         1            5
#
#       SalePrice  Neighborhood_Blueste  Neighborhood_BrDale  \
# ...

# %%
#30.	Нормализовать числовые признаки (MinMaxScaler или StandardScaler).
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = data.drop(columns=['SalePrice'])
scaler_data = scaler.fit_transform(features)

# %%
scaler_data
# Out:
# array([[ 0.37033344,  1.05099379,  0.31172464, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.48251191,  0.15673371,  0.31172464, ..., -0.13199092,
#         -0.16347148, 11.47725023],
#        [ 0.51501256,  0.9847523 ,  0.31172464, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        ...,
#        [ 1.56964722, -1.00249232, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.83278768, -0.70440562, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.49393395, -0.20759447, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888]])

# %%
#32.	Разделить данные на X и y, где y = SalePrice.
x = scaler_data
y = data['SalePrice']

# %%
#33.	Разбить данные на train/test (train_test_split, 80/20).
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#34.	Построить модель LinearRegression() из sklearn.linear_model.
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8267380266474198

# %%
import joblib

joblib.dump(model, 'model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
data.columns
# Out:
# Index(['GrLivArea', 'YearBuilt', 'GarageCars', 'TotalBsmtSF', 'FullBath',
#        'OverallQual', 'SalePrice', 'Neighborhood_Blueste',
#        'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_ClearCr',
#        'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 'Neighborhood_Edwards',
#        'Neighborhood_Gilbert', 'Neighborhood_IDOTRR', 'Neighborhood_MeadowV',
#        'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NPkVill',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
#        'Neighborhood_OldTown', 'Neighborhood_SWISU', 'Neighborhood_Sawyer',
#        'Neighborhood_SawyerW', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
#        'Neighborhood_Timber', 'Neighborhood_Veenker'],
#       dtype='object')
